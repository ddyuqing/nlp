# %%
 import numpy as np
 import math
 import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
def continue_mult(n):
    resutl=1
    for i in range(1,n+1):
        a=3-2*i
        result*=a
    return result

# %%
def element(n):
    return 1/math.factorial(n)*continue_mult(n)/(2**n)

# %%
a=np.linspace(0,50,1000)

# %%
b=-a-np.cos(a)

# %%
plt.plot(a,b)

# %%
result=pd.Dataframe()
result['phi']=a
for i in range(4):
    result['i='+str(i)]=-i*a*0.5-np.cos(a)
result.to_excel('C:/Users/ddyuqing/OneDrive/文件/THU/畢業/畢業論文/Thesis/pic/1SQUID/result.xlsx')
